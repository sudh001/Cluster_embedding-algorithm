# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
import cluster_embedding_util as clemb

# %%
G = nx.karate_club_graph()

# %%
cls = clemb.Cluster_embedding(G)

# %%
cls.fit(5)

# %%
cls.plot_graph()
